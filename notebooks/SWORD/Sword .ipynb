// %% [markdown]
// - 谓词
// - 谓词演算
// - 形式语言
// - 真值表
// - 图论
// - 上下文无关文法
// - 正则文法
// - 数据结构
// - 伪代码
// - 尾递归
// - 堆栈
// - cgi
// - servlet
// - rmi
// - pipeline
// - merge
// - 收敛
// - 时空复杂度
// - gc
// - 错误
// - 错误处理
// - 加法器， 寄存器
// - 编译器
// - JIT/AOT
// - LLVM
// - GCC
// - 驱动
// - 汇编
// - 类型（强弱）
// - 第一类公民
// - 流
// - 回调
// - 编码器
// - 译码器
// - 网络
// - http
// - http 客户端
// - http 服务器
// - 进程
// - 线程
// - 数据库
// - 数据仓库
// - 数据库管理系统
// - 对象关系映射
// - 懒加载
// - 读
// - 写
// - nlp
// - ai
// - vr
// - iot
// - 三层架构
// - 服务发现
// - 服务i注册
// - 容器
// - 镜像
// - 容灾
// - 负载均衡
// - 等价关系
// - 偏序关系
// - 等价类
// - 接口
// - 可序列化
// - 可比较
// - 偏序关系
// - 函数式编程
// - 命令式编程
// - 编程风格
// - 变量命名
// - 操作系统
// - 输入与输出
// - context - 上下文
// - scope
// - session - 会话
// - cwe
// - 存储
// - 持久化
// - 散列表
// - 分布式
// - 安全
// - 加密
// - 信息
// - 数据
// - 熵
// - 统计
// - 矩阵
// - 时间序列
// - 随机变量
// - 数学分析
// - 范式
// - bnf
// - 红黑树
// - 遍历
// - 递归
// - 枚举
// - 穷举
// - 归纳
// - 演绎
// - 关系
// - 对象
// - 面向对象
// - 过程
// - 复用
// - 效率
// - 缓存
// - 计算机词汇
// - token
// - IAM
// - 访问控制
// - 版本
// - 修改
// - 元数据
// - 文件
// - 文件服务器
// - 事务
// - 句柄
// - 二分法
// - 极大似然估计
// - 积分
// - 差分
// - 梯度
// - 回归
// - 认证
// - 授权
// - 机器学习
// - 人工智能
// - 编程语言
// - 编译
// - 图形界面
// - 渲染
// - 观察者
// - 数据绑定
// - 监听
// - 同步
// - 异步
// - 阻塞
// - 并发
// - 冗余
// - 吞吐
// - 总线
// - 算法
// - 命题
// - 命题的指派
// - 命题的成真指派
// - 抽象代数： 群，环，群，域
